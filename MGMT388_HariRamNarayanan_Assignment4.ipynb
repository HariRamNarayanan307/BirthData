# %% [markdown]
# <a href="https://colab.research.google.com/github/HariRamNarayanan307/BirthData/blob/main/MGMT388_HariRamNarayanan_Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_csv('/content/insurance.csv')

# %%
# Question 1
